# %%
st = "techie solution" # str are immmutable 
print(st.replace("techIe","cass"))
# Out:
# techie solution

# %% [markdown]
# find the position of the second i in "techie solution" using the index function.

# %%
st.index("i", 5)
# Out:
# 12

# %%
st.index("c")
print(len(st)) #to check the length of a string or list(array)
# Out:
# 15

# %%
dummyList = [1, 23, 2.3, 'test']
dummyList.append()
dummyList.pop()
dummyList.remove(23)
print(dummyList)
# Out:
# [1, 2.3]

# %%
# dictionary // dict: key : value // like an object
dt = {'name': 'rocky', 'subject': 'Math', 'age': 25}
print(dt)
# Out:
# {'name': 'rocky', 'subject': 'Math', 'age': 25}
