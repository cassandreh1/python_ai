# %%
pip install openai
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# To load from .env file

# %%
pip install python-dotenv
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os 
load_dotenv()
# Out:
# True

# %%
api_ky = os.getenv("OPENAI_API_KEY")
client = OpenAI(api_key=api_ky)

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": "Who is the prime minister of India?"}
    ]
)
print(response.choices[0].message.content)
# Out:
# As of my last update, the Prime Minister of India is Narendra Modi. He has been in office since May 26, 2014. Please verify with current sources, as political positions can change.

# %%
query = input("Please ask something : ")
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": query}
    ],
    max_tokens=50
)
print(response.choices[0].message.content)
# Out:
# I am unable to provide real-time data, including current weather information. To find the weather in Florida today, I recommend checking a reliable weather website, a weather app, or a local news channel.

# %%
# prompt to pass the input text + image(internet)
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "what's in this image?"},
                {
                    "type": "image_url",
                    "image_url": {
                        "url": "https://api.nga.gov/iiif/a2e6da57-3cd1-4235-b20e-95dcaefed6c8/full/!800,800/0/default.jpg"
                    }
                }
            ]
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# This image is a painting of a young woman seated in a chair. She has dark hair styled back with a red ribbon, and is wearing a dress with a striped, red and dark blue top adorned with gold buttons and a blue skirt with orange polka dots. She holds a small bouquet of flowers in her lap, and the background is a muted light blue-green color. The painting style features bold, visible brush strokes and vibrant colors.

# %%
# image that present on your local
import base64

with open("rag_process.PNG", "rb") as file:
    image_in_base64 = base64.b64encode(file.read()).decode("utf-8")

response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "what's in this image?"},
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jped;base64,{image_in_base64}"
                    }
                }
            ]
        }
    ]
)

print(response.choices[0].message.content)
